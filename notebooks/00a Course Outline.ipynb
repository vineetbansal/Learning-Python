# %% [markdown]
# Class 1
#
#     - Motivation
#     - Installation
#     - Python Terminal
#     - Saving and running a very simple program
#     - Jupyter Notebooks introduction
#     - Saving and running notebooks
#     - Using Jupyter to look up help at any point; other useful Jupyter commands
#
#     - Variables
#         - Assigning
#         - Overwriting
#             - Augmented assignments (+=, -= etc)
#         - The 'id' function
#         - Naming rules
#         - Mnemonic naming
#
#      - Operators
#         - Math operators (+, -, *, /, //, %, **)
#         - Operator precedence
#         - Parenthesizing
#
#     - Reserved Words
#     - Calling built-in functions
#     - Importing modules and using module functions/constants (math)
#
#     - Comparisons and Logic
#         - Comparison operators (==, !=, >, <, >=, <=)
#         - Logic Operators (not, and, or)
#         - Boolean True/False
#         - Special value, None
#
#     - Immutability and Identity
#         - Integers and booleans and Immutable
#         - the 'is' operator (also 'is not')
#
#     - Variables have types
#         - Numeric Types
#         - Integers
#         - Floating point operations are not exact (0.1+0.2)
#             - Brief Interlude on fractional representation in binary
#         - Integer vs. Floating point division (Python 2 vs 3)
#         - Explicit Type conversion
#
#     - A simple program
#         - Use input/print to build a simple Celsius -> Fahrenheit convertor
#         - Commenting
#         - Saving and re-running code later (Windows Explorer/Finder + Terminal)
#
#
# Class 2
#
#     - Strings
#         - Defining
#         - Implict conversion to strings
#         - Escape sequences
#         - Unicode support
#
#         - Indexing and Slicing (Useful information for lists later)
#             - Rationale of 0-indexing, start-inclusive, end-exclusive range selection
#
#         - Operators on strings (+, *)
#         - Immutability of strings
#         - Built-in function 'len'
#         - String methods
#             - startswith, endswith, replace, index, upper, lower, strip, lstrip, rstrip,
#
#
# Class 3
#
#     - Lists
#         - Initializing and Indexing
#         - Lists and Mutability
#         - Built-in function 'len'
#         - List methods (append, extend, index, sort)
#         - In place methods vs copying methods - sort, reverse
#         - sort (in-place method) vs. sorted (built-in, makes a copy)
#
#     - Tuples (optional)
#         - Initializing and Indexing
#         - Why are they useful? Use cases?
#         - Tuple packing, unpacking
#
#     - Strings/Lists/Tuples as Iterable objects -> for loops
#         - Python Indentation (tabs vs. spaces)
#         - Motivating Examples
#             - Calculate the factorial of a given number
#             - Find the max of given positive numbers
#             - Find the min of positive numbers (Good use case of NoneType!)
#             - the 'range' type
#
#     - Control Flow
#         - if/elif/else
#         - Fizbuzz Program
#         - Use input/print/if to find if a given year is a leap year
#         - while loops
#         - break/pass/continue
#
#     - File Input/Output
#         - Opening and closing a file
#         - File open modes
#         - Writing to a file (f.write)
#         - Reading from a file (f.read, f.readline, f.readlines, files as iterables of lines)
#         - Basic Plotting with Matlab (uses lists as a prerequisite)
#         - Motivating Example - character mentions in works of Literature
#
#
# Class 4
#
#     - Functions
#         - Defining
#         - Arguments/Return Values
#         - Optional arguments
#         - Positional/Keyword arguments
#         - Functions as first-class citizens in Python
#
#     - Numpy
#         - Basic Array Methods
#         - Matrices
#         - Indexing and Manipulation of ndarrays
#         - Common Matrix operations
#
# Class 5
#
#     - Data Analysis with Pandas
#
#     - Modules and Packages
#         - How popular modules are structured/distributed
#         - Creating your own
#
# Class 6
#
#     - Object Oriented Programming (optional)
#         - Motivation
#         - Defining a class
#         - Regular Methods (no staticmethods etc.)
#         - Access level for variables and best practices
#         - Use cases
#
#     - Error Handling
#         - try/except
#         - When to catch errors. Best practices
#
#     - Optional - As time permits
#         - Pythonic Idioms for "good code"
#         - Where to go from here..
